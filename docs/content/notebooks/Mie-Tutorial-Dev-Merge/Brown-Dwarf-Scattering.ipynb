# %% [markdown]
# # Generating Brown Dwarf / Directly Imaged Planet Emission Spectra with Scattering
#
# ### (work in progress)
#
# This tutorial demonstrates how to compute the direct emission spectrum of a directly imaged object (brown dwarf or directly imaged exoplanet).

# %% [markdown]
# ### System properties
#
# For a directly observed object, we want to compute a model of the flux observed at Earth, $F_p$. We don't have to consider a star in this case, but we do have to provide the distance to the system.

# %%
from POSEIDON.core import create_planet
from POSEIDON.constants import R_J
from scipy.constants import parsec as pc

#***** Define planet / brown dwarf properties *****#

planet_name = 'H$_2$O Rich Y Dwarf'  # Planet name used for plots, output files etc.

R_p = 1.1481664*R_J   # Planetary radius (m)
log_g = 4.76          # log_10 gravitational field of planet (cm/s^2)

d = 2.28*pc          # Distance to system (m)
d_err = 0.01*pc    # Error in a priori system distance

# Create the planet object
planet = create_planet(planet_name, R_p, log_g = log_g, d = d, d_err = d_err)

# No star in this case
star = None

# %% [markdown]
# ### A Basic Y Dwarf Model

# %% [markdown]
# We'll make a simple cloud-free T dwarf model loosely on the retrieved parameters from Line+2015.

# %%
from POSEIDON.core import define_model

#***** Define model *****#

model_name = 'Scattering_test'  # Model name used for plots, output files etc.
#model_name = 'PT_test'         # Model name used for plots, output files etc.

bulk_species = ['H2', 'He']
param_species = ['H2O', 'CH4', 'CO', 'CO2', 'NH3', 'HCN', 'Na', 'K']
aerosol_species = ['H2O']

# Create the model object
model_no_scat = define_model(model_name, bulk_species, param_species, 
                             object_type = 'directly_imaged', gravity_setting = 'free',
                             PT_profile = 'slope', 
                             cloud_model = 'Mie', cloud_type = 'uniform_X',
                             aerosol_species = aerosol_species,
                             scattering = False)

model_scat = define_model(model_name, bulk_species, param_species, 
                          object_type = 'directly_imaged', gravity_setting = 'free',
                          PT_profile = 'slope', 
                          cloud_model = 'Mie', cloud_type = 'uniform_X',
                          aerosol_species = aerosol_species,
                          scattering = True)

# Check the free parameters defining this model
print("Free parameters: " + str(model_no_scat['param_names']))
# Out:
# /Users/elijahmullens/Desktop/POSEIDON-V1-1/POSEIDON/absorption.py:1493: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def store_Rayleigh_eta_LBL(wl_model, chemical_species):
# Reading in database for aerosol cross sections...
# Reading in database for aerosol cross sections...
# Free parameters: ['R_p_ref' 'log_g' 'd' 'T_phot' 'Delta_T_10-1mb' 'Delta_T_100-10mb'
#  'Delta_T_1-0.1b' 'Delta_T_3.2-1b' 'Delta_T_10-3.2b' 'Delta_T_32-10b'
#  'Delta_T_100-32b' 'log_H2O' 'log_CH4' 'log_CO' 'log_CO2' 'log_NH3'
#  'log_HCN' 'log_Na' 'log_K' 'log_r_m_H2O' 'log_X_H2O']

# %%
import numpy as np
from POSEIDON.core import make_atmosphere
from POSEIDON.clouds_make_database import load_refractive_indices_from_file
from POSEIDON.core import wl_grid_constant_R

# Specify the pressure grid of the atmosphere
P_min = 1.0e-3    # 1 mbar
P_max = 100       # 100 bar
N_layers = 100    # 100 layers

#***** Wavelength grid *****#
 
wl_min = 0.4      # Minimum wavelength (um)
wl_max = 13      # Maximum wavelength (um)
R = 10000    # Spectral resolution of grid

wl = wl_grid_constant_R(wl_min, wl_max, R)

# We'll space the layers uniformly in log-pressure
P = np.logspace(np.log10(P_max), np.log10(P_min), N_layers)

# Specify the reference pressure and radius
P_ref = 10.0   # Reference pressure (bar)
R_p_ref = R_p  # Radius at reference pressure

# Provide a specific set of model parameters for the atmosphere 
PT_params = np.array([900.0/2, 0, 100/2, 300/2, 200/2, 300/2, 400/2, 530/2])
#PT_params = np.array([2120.4, 125.62, 513.495, 715.096, 233.445, 904.711, 952.029, 350.513])
log_X_params = np.array([[-3.45, -3.40, -7.53, -7.76, -4.64, -20.0, -5.50, -6.69]])

# Cloud Params uniform x
log_r_m                 =   0
log_X_Mie               =   -18

# Preload the refractive indices from the file 
file_name = './H2O_complex.txt'
r_i_real, r_i_complex = load_refractive_indices_from_file(wl, file_name)

cloud_params = np.array([log_r_m, log_X_Mie, r_i_real, r_i_complex])

# Generate the atmosphere
atmosphere = make_atmosphere(planet, model_no_scat, P, P_ref, R_p_ref, PT_params, 
                             log_X_params, cloud_params, log_g = log_g)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 42
#      39 cloud_params = np.array([log_r_m, log_X_Mie, r_i_real, r_i_complex])
#      41 # Generate the atmosphere
# ---> 42 atmosphere = make_atmosphere(planet, model_no_scat, P, P_ref, R_p_ref, PT_params,
#      43                              log_X_params, cloud_params, log_g = log_g)
#
# File ~/Desktop/POSEIDON-V1-1/POSEIDON/core.py:895, in make_atmosphere(planet, model, P, P_ref, R_p_ref, PT_params, log_X_params, cloud_params, geometry_params, log_g, T_input, X_input, P_surf, P_param_set, He_fraction, N_slice_EM, N_slice_DN, constant_gravity, chemistry_grid)
#     877 T, n, r, r_up, r_low, \
#     878 dr, mu, X, X_active, \
#     879 X_CIA, X_ff, X_bf, \
#    (...)
#     885                        T_input, X_input, P_param_set, constant_gravity,
#     886                        chemistry_grid)
#     888 #***** Store cloud / haze / aerosol properties *****#
#     890 kappa_cloud_0, P_cloud, \
#     891 f_cloud, phi_cloud_0, \
#     892 theta_cloud_0, \
#     893 a, gamma, \
#     894 r_m, log_n_max, fractional_scale_height, \
# --> 895 r_i_real, r_i_complex, log_X_Mie, P_cloud_bottom = unpack_cloud_params(param_names, cloud_params, cloud_model, cloud_dim,
#     896                                                                        N_params_cum, TwoD_type)
#     898 # Temporary H for testing
#     899 g = g_p * (R_p_ref / r)**2
#
# File ~/Desktop/POSEIDON-V1-1/POSEIDON/parameters.py:1607, in unpack_cloud_params(param_names, clouds_in, cloud_model, cloud_dim, N_params_cumulative, TwoD_type)
#    1605         r_i_complex = clouds_in[np.where(cloud_param_names == 'r_i_complex')[0][0]]
#    1606 else:
# -> 1607     r_m = np.float_power(10.0,clouds_in[np.where(np.char.find(cloud_param_names, 'log_r_m')!= -1)[0]])
#    1608     log_X_Mie = clouds_in[np.where(np.char.find(cloud_param_names, 'log_X')!= -1)[0]]
#    1609     r_i_real = 0
#
# TypeError: ufunc 'float_power' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# Let's see what our atmosphere looks like.

# %%
from POSEIDON.visuals import plot_PT, plot_chem

# Produce plots of atmospheric properties
fig_PT = plot_PT(planet, model_no_scat, atmosphere, log_P_max = 2.0)
#fig_chem = plot_chem(planet, model, atmosphere, 
#                     plot_species = ['H2O', 'CH4', 'CO', 'CO2', 'NH3', 'Na', 'K'],
#                     log_X_min = -9, log_P_max = 2.0)

# %% [markdown]
# **Pre-load Opacities**

# %%
from POSEIDON.core import read_opacities, wl_grid_constant_R

#***** Wavelength grid *****#
 
wl_min = 0.4      # Minimum wavelength (um)
wl_max = 13      # Maximum wavelength (um)
R = 10000    # Spectral resolution of grid

wl = wl_grid_constant_R(wl_min, wl_max, R)

#***** Read opacity data *****#

opacity_treatment = 'opacity_sampling'

# Define fine temperature grid (K)
T_fine_min = 100     # 400 K lower limit suffices for a typical hot Jupiter
T_fine_max = 1100    # 2000 K upper limit suffices for a typical hot Jupiter
T_fine_step = 10     # 10 K steps are a good tradeoff between accuracy and RAM

T_fine = np.arange(T_fine_min, (T_fine_max + T_fine_step), T_fine_step)

# Define fine pressure grid (log10(P/bar))
log_P_fine_min = -4.0   # 1 ubar is the lowest pressure in the opacity database
log_P_fine_max = 2.0    # 100 bar is the highest pressure in the opacity database
log_P_fine_step = 0.2   # 0.2 dex steps are a good tradeoff between accuracy and RAM

log_P_fine = np.arange(log_P_fine_min, (log_P_fine_max + log_P_fine_step), 
                       log_P_fine_step)

# Now we can pre-interpolate the sampled opacities (may take up to a minute)
opac = read_opacities(model_no_scat, wl, opacity_treatment, T_fine, log_P_fine)
# Out:
# Reading in cross sections in opacity sampling mode...
# H2-H2 done
# H2-He done
# H2-CH4 done
# CO2-H2 done
# CO2-CO2 done
# CO2-CH4 done
# H2O done
# CH4 done
# CO done
# CO2 done
# NH3 done
# HCN done
# Na done
# K done
# Opacity pre-interpolation complete.

# %% [markdown]
# ### Computing Emission Spectra
#
# Now we can generate the emission spectrum of our brown dwarf.

# %%
from POSEIDON.core import compute_spectrum
from POSEIDON.visuals import plot_spectra
from POSEIDON.utility import plot_collection

# Generate planet surface flux
Fp_no_scat = compute_spectrum(planet, star, model_no_scat, atmosphere, opac, wl, 
                              spectrum_type = 'direct_emission', save_spectrum = True)
Fp_scat = compute_spectrum(planet, star, model_scat, atmosphere, opac, wl, 
                           spectrum_type = 'direct_emission', save_spectrum = True)

spectra = []   
spectra = plot_collection(Fp_no_scat, wl, collection = spectra)
spectra = plot_collection(Fp_scat, wl, collection = spectra)


# Produce figure and save to file
fig_spec = plot_spectra(spectra, planet, R_to_bin = 100, plot_full_res = True,
                        y_unit = 'Fp', spectra_labels = ['No Scattering', 'Scattering'],
                        legend_location = 'center left', wl_axis = 'log', colour_list = ['#ff7f00', '#984ea3'])

# %%
fig_spec = plot_spectra(spectra, planet, R_to_bin = 100, plot_full_res = True,
                        y_unit = 'Fp', spectra_labels = ['No Scattering', 'Rayleigh Scattering'],
                        legend_location = 'upper right', wl_axis = 'log',
                        wl_max = 0.8, y_max = 0.1e-10)

# %%
# %timeit -n 10 compute_spectrum(planet, star, model_no_scat, atmosphere, opac, wl, spectrum_type = 'direct_emission')
# %timeit -n 10 compute_spectrum(planet, star, model_scat, atmosphere, opac, wl, spectrum_type = 'direct_emission')
# Out:
# 476 ms ± 6.16 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 2.51 s ± 95 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
print(1/0)

# %%
from POSEIDON.clouds_aerosols_emission import load_aerosol_grid, interpolate_sigma_Mie_grid
import matplotlib.pyplot as plt 

# Load in the grid with three aerosols
aerosol_grid = load_aerosol_grid(['SiO2_amorph'])

# Test to see if the cross sections come out with SiO2 particle, 0.01 um sized
r_m = 9
sigma_Mie_interp_array = interpolate_sigma_Mie_grid(aerosol_grid, wl, [r_m], ['SiO2_amorph'],)

label = 'r_m (um) : ' + str(r_m)
title =' Effective Extinction Cross Section'
plt.plot(wl,sigma_Mie_interp_array['SiO2_amorph']['eff_ext'], label = label)
plt.legend()
plt.title(title)
plt.xlabel('Wavelengths (um)')
plt.ylabel('Effective Cross Section')
plt.show()

label = 'r_m (um) : ' + str(r_m)
title =' SSA'
plt.plot(wl,sigma_Mie_interp_array['SiO2_amorph']['eff_w'], label = label)
plt.legend()
plt.title(title)
plt.xlabel('Wavelengths (um)')
plt.ylabel('SSA')
plt.show()

label = 'r_m (um) : ' + str(r_m)
title ='g'
plt.plot(wl,sigma_Mie_interp_array['SiO2_amorph']['eff_g'], label = label)
plt.legend()
plt.title(title)
plt.xlabel('Wavelengths (um)')
plt.ylabel('g')
plt.show()

# %%
from POSEIDON.clouds_make_database_emission import plot_refractive_indices_from_file, plot_effective_cross_section_from_file
import numpy as np 
from POSEIDON.core import wl_grid_constant_R

wl_min = 0.4      # Minimum wavelength (um)
wl_max = 13      # Maximum wavelength (um)
R = 10000    # Spectral resolution of grid

wl = wl_grid_constant_R(wl_min, wl_max, R)

# First, lets check how the cross sections that our own file : 'H2O_complex.txt' makes
file_name = './H2O_complex.txt'

# Plotting the refractive indices 
plot_refractive_indices_from_file(wl, file_name)

# Plotting the cross section from LX_MIE 
r_m = 10**0
plot_effective_cross_section_from_file(wl, r_m, file_name)
