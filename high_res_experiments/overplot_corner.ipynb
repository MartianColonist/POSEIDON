# %%
# %%
from POSEIDON.core import create_star, create_planet
from POSEIDON.constants import R_Sun, R_J, M_J
from POSEIDON.visuals import *
import pickle

# ***** Define stellar properties *****#
R_s = 1.21 * R_Sun  # Stellar radius (m)
T_s = 5605.0  # Stellar effective temperature (K)
Met_s = -0.04  # Stellar metallicity [log10(Fe/H_star / Fe/H_solar)]
log_g_s = 4.56  # Stellar log surface gravity (log10(cm/s^2) by convention)
# ***** Define planet properties *****#

planet_name = "WASP-77Ab"  # Planet name used for plots, output files etc.

R_p = 1.21 * R_J  # Planetary radius (m)
M_p = 0.07 * M_J  # Mass of planet (kg)
g_p = 4.3712  # Gravitational field of planet (m/s^2)
T_eq = 1043.8  # Equilibrium temperature (K)

# Create the planet object
planet = create_planet(planet_name, R_p, mass=M_p, gravity=g_p, T_eq=T_eq)

from POSEIDON.core import define_model

bulk_species = ["H2", "He"]  # H2 + He comprises the bulk atmosphere
param_species = ["H2O", "CO"]  # H2O, CO as in Brogi & Line

method = "pca"
# high_res_params = ['a', 'b', 'dPhi', 'K_p', 'V_sys', 'W_conv']
high_res_params = ["a", "K_p", "V_sys"]

model_1 = define_model(
    "H2O, CO retrieval",
    bulk_species,
    param_species,
    PT_profile="Madhu",
    high_res_params=high_res_params,
    reference_parameter="R_p_ref",
)


model_2 = define_model(
    "H2O, CO retrieval 400",
    bulk_species,
    param_species,
    PT_profile="Madhu",
    high_res_params=high_res_params,
    reference_parameter="R_p_ref",
)

high_res_params = ["K_p", "V_sys", "a"]
model_3 = define_model(
    "H2O, CO retrieval disbale ref",
    bulk_species,
    param_species,
    PT_profile="Madhu",
    high_res_params=high_res_params,
    reference_parameter="None",
)

# %%
from POSEIDON.corner import generate_cornerplot, generate_overplot
import matplotlib.pyplot as plt

params_to_plot = ["log_Fe", "log_Cr", "log_V", "K_p", "V_sys", "W_conv", "log_a"]
fig = generate_overplot(
    planet,
    [model_1, model_2],
    params_to_plot=params_to_plot,
    model_display_names=["Fix R_p run 1", "Fix R_p run 2", "Disable R_p_ref"],
    true_vals=[-4, -4, 192.6, -6.8],
    truth_colour="red",
    colour_schemes=["purple", "green", "orange"],
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.conda/envs/poseidon/lib/python3.9/site-packages/pymultinest/analyse.py:34, in loadtxt2d(intext)
#      33 try:
# ---> 34 	return numpy.loadtxt(intext, ndmin=2)
#      35 except:
#
# File ~/.conda/envs/poseidon/lib/python3.9/site-packages/numpy/lib/npyio.py:1042, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1041 if _is_string_like(fname):
# -> 1042     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1043     fencoding = getattr(fh, 'encoding', 'latin1')
#
# File ~/.conda/envs/poseidon/lib/python3.9/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/.conda/envs/poseidon/lib/python3.9/site-packages/numpy/lib/_datasource.py:532, in DataSource.open(self, path, mode, encoding, newline)
#     531 else:
# --> 532     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: ./POSEIDON_output/WASP-121b/retrievals/MultiNest_raw/Fe, Cr, V isotherm fix Rp-.txt not found.
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /home/ruizhew/POSEIDON/high_res_experiments/overplot_corner.ipynb Cell 2 line 5
#       <a href='vscode-notebook-cell://ssh-remote%2Bhal-1b.astro.cornell.edu/home/ruizhew/POSEIDON/high_res_experiments/overplot_corner.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell://ssh-remote%2Bhal-1b.astro.cornell.edu/home/ruizhew/POSEIDON/high_res_experiments/overplot_corner.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> params_to_plot = ["log_Fe", "log_Cr", "log_V", "K_p", "V_sys", "W_conv", "log_a"]
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bhal-1b.astro.cornell.edu/home/ruizhew/POSEIDON/high_res_experiments/overplot_corner.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> fig = generate_overplot(
#       <a href='vscode-notebook-cell://ssh-remote%2Bhal-1b.astro.cornell.edu/home/ruizhew/POSEIDON/high_res_experiments/overplot_corner.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     planet,
#       <a href='vscode-notebook-cell://ssh-remote%2Bhal-1b.astro.cornell.edu/home/ruizhew/POSEIDON/high_res_experiments/overplot_corner.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     [model_1, model_2],
#       <a href='vscode-notebook-cell://ssh-remote%2Bhal-1b.astro.cornell.edu/home/ruizhew/POSEIDON/high_res_experiments/overplot_corner.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     params_to_plot=params_to_plot,
#       <a href='vscode-notebook-cell://ssh-remote%2Bhal-1b.astro.cornell.edu/home/ruizhew/POSEIDON/high_res_experiments/overplot_corner.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>     model_display_names=["Fix R_p run 1", "Fix R_p run 2", "Disable R_p_ref"],
#      <a href='vscode-notebook-cell://ssh-remote%2Bhal-1b.astro.cornell.edu/home/ruizhew/POSEIDON/high_res_experiments/overplot_corner.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a>     true_vals=[-4, -4, 192.6, -6.8],
#      <a href='vscode-notebook-cell://ssh-remote%2Bhal-1b.astro.cornell.edu/home/ruizhew/POSEIDON/high_res_experiments/overplot_corner.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     truth_colour="red",
#      <a href='vscode-notebook-cell://ssh-remote%2Bhal-1b.astro.cornell.edu/home/ruizhew/POSEIDON/high_res_experiments/overplot_corner.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>     colour_schemes=["purple", "green", "orange"],
#      <a href='vscode-notebook-cell://ssh-remote%2Bhal-1b.astro.cornell.edu/home/ruizhew/POSEIDON/high_res_experiments/overplot_corner.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> )
#
# File ~/.conda/envs/poseidon/lib/python3.9/site-packages/POSEIDON/corner.py:991, in generate_overplot(planet, models, params_to_plot, model_display_names, true_vals, truth_colour, colour_schemes, span)
#     987 # Run PyMultiNest analyser to extract posterior samples and model evidence
#     988 a = pymultinest.Analyzer(
#     989     n_params, outputfiles_basename=output_prefix, verbose=False
#     990 )
# --> 991 s = a.get_stats()
#     993 print(f"Generating corner plot {model_i}...")
#     995 # Extract quantities needed to use the Dynesty corner plotting script
#
# File ~/.conda/envs/poseidon/lib/python3.9/site-packages/pymultinest/analyse.py:123, in Analyzer.get_stats(self)
#     122 def get_stats(self):
# --> 123 	posterior = self.get_data()
#     125 	stats = []
#     127 	for i in range(2, posterior.shape[1]):
#
# File ~/.conda/envs/poseidon/lib/python3.9/site-packages/pymultinest/analyse.py:86, in Analyzer.get_data(self)
#      82 """
#      83 	fetches self.data_file
#      84 """
#      85 if not hasattr(self, 'data'):
# ---> 86 	self.data = loadtxt2d(self.data_file)
#      87 return self.data
#
# File ~/.conda/envs/poseidon/lib/python3.9/site-packages/pymultinest/analyse.py:36, in loadtxt2d(intext)
#      34 	return numpy.loadtxt(intext, ndmin=2)
#      35 except:
# ---> 36 	return numpy.loadtxt(intext)
#
# File ~/.conda/envs/poseidon/lib/python3.9/site-packages/numpy/lib/npyio.py:1042, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1040     fname = os_fspath(fname)
#    1041 if _is_string_like(fname):
# -> 1042     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1043     fencoding = getattr(fh, 'encoding', 'latin1')
#    1044     line_iter = iter(fh)
#
# File ~/.conda/envs/poseidon/lib/python3.9/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/.conda/envs/poseidon/lib/python3.9/site-packages/numpy/lib/_datasource.py:532, in DataSource.open(self, path, mode, encoding, newline)
#     529     return _file_openers[ext](found, mode=mode,
#     530                               encoding=encoding, newline=newline)
#     531 else:
# --> 532     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: ./POSEIDON_output/WASP-121b/retrievals/MultiNest_raw/Fe, Cr, V isotherm fix Rp-.txt not found.

# %%
params_to_plot = ["log_H2O", "log_CO", "K_p", "V_sys", "a"]
fig = generate_overplot(
    planet,
    [model_1, model_2],
    params_to_plot=params_to_plot,
    model_display_names=["Fix R_p run 1", "Fix R_p run 2"],
    true_vals=[-4, -4, 192.6, -6.8, 1],
    truth_colour="red",
    colour_schemes=["purple", "green", "orange"],
)
# Out:
# Generating corner plot 0...
# Generating corner plot 1...

# %%
params_to_plot = ["R_p_ref", "log_H2O", "log_CO", "K_p", "V_sys", "a"]
fig = generate_cornerplot(
    planet,
    model_1,
    params_to_plot=params_to_plot,
    true_vals=[None, -4, -4, 192.6, -6.8, None],
)
# Out:
# Generating corner plot ...
